# %%
import PSEmulator
# %matplotlib inline

# %%
Emu1 = PSEmulator.PSEmulator('/dev/ttyUSB0', 9600)
# Out:
# Connecting serial device: /dev/ttyUSB0
# Serial connection: established

# %%
Emu1.stand_by()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22716/1486712407.py in <module>
# ----> 1 Emu1.stand_by()
#
# ~/PSEmulator/PSEmulator.py in stand_by(self)
#     145                 self.passed_time = time.time() - self.start_time
#     146                 self.prev_time = time.time()
# --> 147                 self.update_canvas(fig, ax1, ax2, self.passed_time, self.get_voltage(), self.get_current())
#     148
#     149             if self.conn.in_waiting > 0:
#
# ~/PSEmulator/PSEmulator.py in update_canvas(self, _fig, _ax1, _ax2, p_time, volt, curr)
#     121         _ax2.set_xlim(p_time - 30, p_time + 30)
#     122         _ax2.plot(self.time_list, self.curr_list, marker = 'o', color = 'r')
# --> 123         display(_fig)
#     124         clear_output(wait = True)
#     125         plt.pause(0.1)
#
# ...
